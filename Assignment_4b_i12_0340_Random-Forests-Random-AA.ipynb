# %% [markdown]
# #Assignment No 4b
# ######*Sibt ul Hussain*
# ----
# ##Goal
#
# Your goal in this assigment is to implement and test different variants of Random Forests. For this part you will be implemented randomized version of **Random Axis-Aligned** weak learner based Random Forest, i.e. you will be randomly selecting the feature from all set of features and than setting the threshold by randomly selecting a threshold.
#
# **Note** Please note that you are allowed to use only those libraries which we have discussed in the class, i.e. numpy, scipy, pandas.
#
# ##TODO:
#
# **Complete the code in files `randomForest.py`, `tree.py` and `weakLearner.py` by writing the missing code.**
#
# ##Submission Instructions
# You are required to submit the original notebook file on the Slate (with .ipynb extension), with complete set of outputs. Students failing to do so will get zero marks.
#
# *Please read each step carefully and understand it fully before proceeding with code writing*
#
# ##Plagiarism
# Any form of plagiarism will not be tolerated and result in 0 marks.

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary 
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
# %load_ext autoreload 
# %autoreload 2
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..
import time

# %%
# Create some dummy data for testing
np.random.seed(seed=99)

# %% [markdown]
# ## Let's cook some data up for a multi-class classification problem...

# %%
#generate training and testing set...by sampling from mutli-variate Gaussian
cp=5
nclasses=2
mean1 = [-cp,-cp]
mean2 = [cp,cp]
mean3 = [cp,-cp]
mean4 = [-cp,cp]
cov = [[3.0,0.0],[0.0,3.0]] 

#create some points for the training set...
nexamples=2000
x1 = np.random.multivariate_normal(mean1,cov,nexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,nexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,nexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,nexamples/4)

X=np.vstack((x1,x2,x3,x4))
Y=np.vstack((1*np.ones((nexamples/4,1)),2*np.ones((nexamples/4,1)),3*np.ones((nexamples/4,1)),4*np.ones((nexamples/4,1))))


plt.scatter(x1[:,0],x1[:,1], c='r', s=100)
plt.scatter(x2[:,0],x2[:,1], c='g', s=100)            
plt.scatter(x3[:,0],x3[:,1], c='b', s=100)
plt.scatter(x4[:,0],x4[:,1], c='y', s=100)            



plt.title("Multi-class Classification")
plt.xlabel("feature $x_1$")
plt.ylabel("feature $x_2$")
plt.legend(['r','g','b','y'])
fig_ml_in_10 = plt.gcf()
plt.savefig('multi-linear-class.svg',format='svg')
#create some points for the training set..

ntexamples=1000
x1 = np.random.multivariate_normal(mean1,cov,ntexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,ntexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,ntexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,ntexamples/4)

Xt=np.vstack((x1,x2,x3,x4))
Yt=np.vstack((1*np.ones((ntexamples/4,1)),2*np.ones((ntexamples/4,1)),3*np.ones((ntexamples/4,1)),4*np.ones((ntexamples/4,1))))

# %%
import randomForest as rf

# %%
rfc=rf.RandomForest(weaklearner='Axis-Aligned-Random')

# %%
print X.shape, Y.shape
# Out:
# (2000, 2) (2000, 1)

# %%
#%debug
rfc.train(X,Y)
# Out:
# Creating Left Child Node With 999 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 982 Examples, and Right Node with 17 Examples
# Creating Left Child Node With 488 Examples, and Right Node with 494 Examples
# Creating Left Child Node With 118 Examples, and Right Node with 370 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=118, classes=[(1.0, 118)]
# Creating Child Node With ClassLabel=1.0, nexamples=370, classes=[(1.0, 369), (4.0, 1)]
# Creating Left Child Node With 86 Examples, and Right Node with 408 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=86, classes=[(1.0, 3), (4.0, 83)]
# Creating Child Node With ClassLabel=4.0, nexamples=408, classes=[(4.0, 408)]
# Creating Left Child Node With 8 Examples, and Right Node with 9 Examples
# Creating Left Child Node With 4 Examples, and Right Node with 4 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=4, classes=[(1.0, 3), (4.0, 1)]
# Creating Child Node With ClassLabel=1.0, nexamples=4, classes=[(1.0, 4)]
# Creating Left Child Node With 8 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=8, classes=[(2.0, 1), (4.0, 7)]
# Creating Child Node With ClassLabel=2.0, nexamples=1, classes=[(2.0, 1)]
# Creating Left Child Node With 503 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 494 Examples, and Right Node with 9 Examples
# Creating Left Child Node With 399 Examples, and Right Node with 95 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=399, classes=[(1.0, 3), (3.0, 396)]
# Creating Child Node With ClassLabel=3.0, nexamples=95, classes=[(3.0, 95)]
# Creating Left Child Node With 8 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=8, classes=[(3.0, 8)]
# Creating Child Node With ClassLabel=2.0, nexamples=1, classes=[(2.0, 1)]
# Creating Left Child Node With 140 Examples, and Right Node with 358 Examples
# Creating Left Child Node With 10 Examples, and Right Node with 130 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=10, classes=[(2.0, 9), (3.0, 1)]
# Creating Child Node With ClassLabel=2.0, nexamples=130, classes=[(2.0, 130)]
# Creating Left Child Node With 13 Examples, and Right Node with 345 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=13, classes=[(2.0, 13)]
# Creating Child Node With ClassLabel=2.0, nexamples=345, classes=[(2.0, 345)]
# Creating Left Child Node With 973 Examples, and Right Node with 1027 Examples
# Creating Left Child Node With 485 Examples, and Right Node with 488 Examples
# Creating Left Child Node With 227 Examples, and Right Node with 258 Examples
# Creating Left Child Node With 32 Examples, and Right Node with 195 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=32, classes=[(1.0, 32)]
# Creating Child Node With ClassLabel=1.0, nexamples=195, classes=[(1.0, 195)]
# Creating Left Child Node With 253 Examples, and Right Node with 5 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=253, classes=[(1.0, 253)]
# Creating Child Node With ClassLabel=1.0, nexamples=5, classes=[(1.0, 4), (4.0, 1)]
# Creating Left Child Node With 42 Examples, and Right Node with 446 Examples
# Creating Left Child Node With 12 Examples, and Right Node with 30 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=12, classes=[(4.0, 12)]
# Creating Child Node With ClassLabel=4.0, nexamples=30, classes=[(1.0, 3), (4.0, 27)]
# Creating Left Child Node With 136 Examples, and Right Node with 310 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=136, classes=[(4.0, 136)]
# Creating Child Node With ClassLabel=4.0, nexamples=310, classes=[(4.0, 310)]
# Creating Left Child Node With 533 Examples, and Right Node with 494 Examples
# Creating Left Child Node With 12 Examples, and Right Node with 521 Examples
# Creating Left Child Node With 11 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=11, classes=[(1.0, 11)]
# Creating Child Node With ClassLabel=4.0, nexamples=1, classes=[(4.0, 1)]
# Creating Left Child Node With 6 Examples, and Right Node with 515 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=6, classes=[(1.0, 2), (3.0, 4)]
# Creating Child Node With ClassLabel=3.0, nexamples=515, classes=[(2.0, 19), (3.0, 496)]
# Creating Left Child Node With 29 Examples, and Right Node with 465 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 28 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=1, classes=[(2.0, 1)]
# Creating Child Node With ClassLabel=2.0, nexamples=28, classes=[(2.0, 28)]
# Creating Left Child Node With 24 Examples, and Right Node with 441 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=24, classes=[(2.0, 11), (4.0, 13)]
# Creating Child Node With ClassLabel=2.0, nexamples=441, classes=[(2.0, 441)]
# Creating Left Child Node With 1025 Examples, and Right Node with 975 Examples
# Creating Left Child Node With 951 Examples, and Right Node with 74 Examples
# Creating Left Child Node With 116 Examples, and Right Node with 835 Examples
# Creating Left Child Node With 52 Examples, and Right Node with 64 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=52, classes=[(1.0, 52)]
# Creating Child Node With ClassLabel=4.0, nexamples=64, classes=[(4.0, 64)]
# Creating Left Child Node With 450 Examples, and Right Node with 385 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=450, classes=[(1.0, 425), (4.0, 25)]
# Creating Child Node With ClassLabel=4.0, nexamples=385, classes=[(4.0, 385)]
# Creating Left Child Node With 49 Examples, and Right Node with 25 Examples
# Creating Left Child Node With 21 Examples, and Right Node with 28 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=21, classes=[(1.0, 20), (4.0, 1)]
# Creating Child Node With ClassLabel=4.0, nexamples=28, classes=[(2.0, 3), (4.0, 25)]
# Creating Left Child Node With 18 Examples, and Right Node with 7 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=18, classes=[(1.0, 3), (2.0, 6), (3.0, 9)]
# Creating Child Node With ClassLabel=2.0, nexamples=7, classes=[(2.0, 7)]
# Creating Left Child Node With 498 Examples, and Right Node with 477 Examples
# Creating Left Child Node With 484 Examples, and Right Node with 14 Examples
# Creating Left Child Node With 64 Examples, and Right Node with 420 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=64, classes=[(3.0, 64)]
# Creating Child Node With ClassLabel=3.0, nexamples=420, classes=[(3.0, 420)]
# Creating Left Child Node With 6 Examples, and Right Node with 8 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=6, classes=[(2.0, 1), (3.0, 5)]
# Creating Child Node With ClassLabel=2.0, nexamples=8, classes=[(2.0, 6), (3.0, 2)]
# Creating Left Child Node With 429 Examples, and Right Node with 48 Examples
# Creating Left Child Node With 157 Examples, and Right Node with 272 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=157, classes=[(2.0, 157)]
# Creating Child Node With ClassLabel=2.0, nexamples=272, classes=[(2.0, 272)]
# Creating Left Child Node With 47 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=47, classes=[(2.0, 47)]
# Creating Child Node With ClassLabel=2.0, nexamples=1, classes=[(2.0, 1)]
# Creating Left Child Node With 1067 Examples, and Right Node with 933 Examples
# Creating Left Child Node With 528 Examples, and Right Node with 539 Examples
# Creating Left Child Node With 524 Examples, and Right Node with 4 Examples
# Creating Left Child Node With 491 Examples, and Right Node with 33 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=491, classes=[(1.0, 490), (4.0, 1)]
# Creating Child Node With ClassLabel=4.0, nexamples=33, classes=[(1.0, 3), (4.0, 30)]
# Creating Child Node With ClassLabel=1.0, nexamples=4, classes=[(1.0, 3), (4.0, 1)]
# Creating Left Child Node With 500 Examples, and Right Node with 39 Examples
# Creating Left Child Node With 121 Examples, and Right Node with 379 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=121, classes=[(3.0, 121)]
# Creating Child Node With ClassLabel=3.0, nexamples=379, classes=[(1.0, 4), (3.0, 375)]
# Creating Left Child Node With 3 Examples, and Right Node with 36 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=3, classes=[(3.0, 3)]
# Creating Child Node With ClassLabel=2.0, nexamples=36, classes=[(2.0, 35), (3.0, 1)]
# Creating Left Child Node With 931 Examples, and Right Node with 2 Examples
# Creating Left Child Node With 591 Examples, and Right Node with 340 Examples
# Creating Left Child Node With 282 Examples, and Right Node with 309 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=282, classes=[(2.0, 141), (4.0, 141)]
# Creating Child Node With ClassLabel=2.0, nexamples=309, classes=[(2.0, 166), (4.0, 143)]
# Creating Left Child Node With 339 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=339, classes=[(2.0, 157), (4.0, 182)]
# Creating Child Node With ClassLabel=2.0, nexamples=1, classes=[(2.0, 1)]
# Creating Child Node With ClassLabel=4.0, nexamples=2, classes=[(4.0, 2)]
# Creating Left Child Node With 999 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 493 Examples, and Right Node with 506 Examples
# Creating Left Child Node With 476 Examples, and Right Node with 17 Examples
# Creating Left Child Node With 6 Examples, and Right Node with 470 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=6, classes=[(1.0, 6)]
# Creating Child Node With ClassLabel=1.0, nexamples=470, classes=[(1.0, 470)]
# Creating Left Child Node With 13 Examples, and Right Node with 4 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=13, classes=[(1.0, 11), (4.0, 2)]
# Creating Child Node With ClassLabel=1.0, nexamples=4, classes=[(1.0, 4)]
# Creating Left Child Node With 59 Examples, and Right Node with 447 Examples
# Creating Left Child Node With 53 Examples, and Right Node with 6 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=53, classes=[(3.0, 53)]
# Creating Child Node With ClassLabel=3.0, nexamples=6, classes=[(3.0, 6)]
# Creating Left Child Node With 60 Examples, and Right Node with 387 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=60, classes=[(3.0, 60)]
# Creating Child Node With ClassLabel=3.0, nexamples=387, classes=[(1.0, 7), (3.0, 380)]
# Creating Left Child Node With 59 Examples, and Right Node with 942 Examples
# Creating Left Child Node With 11 Examples, and Right Node with 48 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 10 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=1, classes=[(2.0, 1)]
# Creating Child Node With ClassLabel=4.0, nexamples=10, classes=[(2.0, 4), (3.0, 1), (4.0, 5)]
# Creating Left Child Node With 22 Examples, and Right Node with 26 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=22, classes=[(1.0, 2), (4.0, 20)]
# Creating Child Node With ClassLabel=2.0, nexamples=26, classes=[(2.0, 26)]
# Creating Left Child Node With 471 Examples, and Right Node with 471 Examples
# Creating Left Child Node With 122 Examples, and Right Node with 349 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=122, classes=[(4.0, 122)]
# Creating Child Node With ClassLabel=4.0, nexamples=349, classes=[(4.0, 349)]
# Creating Left Child Node With 10 Examples, and Right Node with 461 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=10, classes=[(2.0, 8), (4.0, 2)]
# Creating Child Node With ClassLabel=2.0, nexamples=461, classes=[(2.0, 461)]
# Creating Left Child Node With 997 Examples, and Right Node with 1003 Examples
# Creating Left Child Node With 478 Examples, and Right Node with 519 Examples
# Creating Left Child Node With 189 Examples, and Right Node with 289 Examples
# Creating Left Child Node With 46 Examples, and Right Node with 143 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=46, classes=[(1.0, 46)]
# Creating Child Node With ClassLabel=1.0, nexamples=143, classes=[(1.0, 143)]
# Creating Left Child Node With 284 Examples, and Right Node with 5 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=284, classes=[(1.0, 284)]
# Creating Child Node With ClassLabel=1.0, nexamples=5, classes=[(1.0, 4), (4.0, 1)]
# Creating Left Child Node With 296 Examples, and Right Node with 223 Examples
# Creating Left Child Node With 13 Examples, and Right Node with 283 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=13, classes=[(1.0, 9), (3.0, 4)]
# Creating Child Node With ClassLabel=3.0, nexamples=283, classes=[(3.0, 283)]
# Creating Left Child Node With 12 Examples, and Right Node with 211 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=12, classes=[(1.0, 11), (3.0, 1)]
# Creating Child Node With ClassLabel=3.0, nexamples=211, classes=[(3.0, 211)]
# Creating Left Child Node With 505 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 500 Examples, and Right Node with 5 Examples
# Creating Left Child Node With 18 Examples, and Right Node with 482 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=18, classes=[(1.0, 3), (4.0, 15)]
# Creating Child Node With ClassLabel=4.0, nexamples=482, classes=[(4.0, 482)]
# Creating Child Node With ClassLabel=2.0, nexamples=5, classes=[(2.0, 3), (4.0, 2)]
# Creating Left Child Node With 45 Examples, and Right Node with 453 Examples
# Creating Left Child Node With 12 Examples, and Right Node with 33 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=12, classes=[(2.0, 11), (3.0, 1)]
# Creating Child Node With ClassLabel=2.0, nexamples=33, classes=[(2.0, 33)]
# Creating Left Child Node With 446 Examples, and Right Node with 7 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=446, classes=[(2.0, 446)]
# Creating Child Node With ClassLabel=2.0, nexamples=7, classes=[(2.0, 7)]
# Creating Left Child Node With 982 Examples, and Right Node with 1018 Examples
# Creating Left Child Node With 496 Examples, and Right Node with 486 Examples
# Creating Left Child Node With 67 Examples, and Right Node with 429 Examples
# Creating Left Child Node With 6 Examples, and Right Node with 61 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=6, classes=[(1.0, 6)]
# Creating Child Node With ClassLabel=1.0, nexamples=61, classes=[(1.0, 61)]
# Creating Left Child Node With 374 Examples, and Right Node with 55 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=374, classes=[(1.0, 367), (4.0, 7)]
# Creating Child Node With ClassLabel=1.0, nexamples=55, classes=[(1.0, 55)]
# Creating Left Child Node With 14 Examples, and Right Node with 472 Examples
# Creating Left Child Node With 7 Examples, and Right Node with 7 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=7, classes=[(1.0, 1), (4.0, 6)]
# Creating Child Node With ClassLabel=4.0, nexamples=7, classes=[(4.0, 7)]
# Creating Left Child Node With 46 Examples, and Right Node with 426 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=46, classes=[(4.0, 46)]
# Creating Child Node With ClassLabel=4.0, nexamples=426, classes=[(4.0, 426)]
# Creating Left Child Node With 516 Examples, and Right Node with 502 Examples
# Creating Left Child Node With 509 Examples, and Right Node with 7 Examples
# Creating Left Child Node With 480 Examples, and Right Node with 29 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=480, classes=[(1.0, 10), (3.0, 470)]
# Creating Child Node With ClassLabel=3.0, nexamples=29, classes=[(3.0, 29)]
# Creating Left Child Node With 1 Examples, and Right Node with 6 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=1, classes=[(4.0, 1)]
# Creating Child Node With ClassLabel=2.0, nexamples=6, classes=[(2.0, 5), (3.0, 1)]
# Creating Left Child Node With 494 Examples, and Right Node with 8 Examples
# Creating Left Child Node With 7 Examples, and Right Node with 487 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=7, classes=[(2.0, 1), (4.0, 6)]
# Creating Child Node With ClassLabel=2.0, nexamples=487, classes=[(2.0, 487)]
# Creating Left Child Node With 1 Examples, and Right Node with 7 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=1, classes=[(4.0, 1)]
# Creating Child Node With ClassLabel=2.0, nexamples=7, classes=[(2.0, 7)]
# Creating Left Child Node With 1141 Examples, and Right Node with 859 Examples
# Creating Left Child Node With 557 Examples, and Right Node with 584 Examples
# Creating Left Child Node With 174 Examples, and Right Node with 383 Examples
# Creating Left Child Node With 90 Examples, and Right Node with 84 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=90, classes=[(1.0, 73), (4.0, 17)]
# Creating Child Node With ClassLabel=1.0, nexamples=84, classes=[(1.0, 76), (4.0, 8)]
# Creating Left Child Node With 340 Examples, and Right Node with 43 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=340, classes=[(1.0, 339), (4.0, 1)]
# Creating Child Node With ClassLabel=4.0, nexamples=43, classes=[(1.0, 2), (4.0, 41)]
# Creating Left Child Node With 25 Examples, and Right Node with 559 Examples
# Creating Left Child Node With 21 Examples, and Right Node with 4 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=21, classes=[(1.0, 10), (3.0, 11)]
# Creating Child Node With ClassLabel=2.0, nexamples=4, classes=[(2.0, 3), (4.0, 1)]
# Creating Left Child Node With 252 Examples, and Right Node with 307 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=252, classes=[(2.0, 24), (3.0, 228)]
# Creating Child Node With ClassLabel=3.0, nexamples=307, classes=[(2.0, 46), (3.0, 261)]
# Creating Left Child Node With 857 Examples, and Right Node with 2 Examples
# Creating Left Child Node With 762 Examples, and Right Node with 95 Examples
# Creating Left Child Node With 374 Examples, and Right Node with 388 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=374, classes=[(4.0, 374)]
# Creating Child Node With ClassLabel=2.0, nexamples=388, classes=[(2.0, 386), (4.0, 2)]
# Creating Left Child Node With 57 Examples, and Right Node with 38 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=57, classes=[(2.0, 3), (4.0, 54)]
# Creating Child Node With ClassLabel=2.0, nexamples=38, classes=[(2.0, 38)]
# Creating Child Node With ClassLabel=4.0, nexamples=2, classes=[(4.0, 2)]
# Creating Left Child Node With 987 Examples, and Right Node with 1013 Examples
# Creating Left Child Node With 491 Examples, and Right Node with 496 Examples
# Creating Left Child Node With 252 Examples, and Right Node with 239 Examples
# Creating Left Child Node With 2 Examples, and Right Node with 250 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=2, classes=[(1.0, 2)]
# Creating Child Node With ClassLabel=1.0, nexamples=250, classes=[(1.0, 250)]
# Creating Left Child Node With 237 Examples, and Right Node with 2 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=237, classes=[(1.0, 237)]
# Creating Child Node With ClassLabel=1.0, nexamples=2, classes=[(1.0, 1), (4.0, 1)]
# Creating Left Child Node With 38 Examples, and Right Node with 458 Examples
# Creating Left Child Node With 16 Examples, and Right Node with 22 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=16, classes=[(1.0, 3), (4.0, 13)]
# Creating Child Node With ClassLabel=4.0, nexamples=22, classes=[(4.0, 22)]
# Creating Left Child Node With 451 Examples, and Right Node with 7 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=451, classes=[(4.0, 451)]
# Creating Child Node With ClassLabel=4.0, nexamples=7, classes=[(4.0, 7)]
# Creating Left Child Node With 507 Examples, and Right Node with 506 Examples
# Creating Left Child Node With 460 Examples, and Right Node with 47 Examples
# Creating Left Child Node With 19 Examples, and Right Node with 441 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=19, classes=[(1.0, 6), (3.0, 13)]
# Creating Child Node With ClassLabel=3.0, nexamples=441, classes=[(3.0, 441)]
# Creating Left Child Node With 1 Examples, and Right Node with 46 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=1, classes=[(1.0, 1)]
# Creating Child Node With ClassLabel=3.0, nexamples=46, classes=[(2.0, 1), (3.0, 45)]
# Creating Left Child Node With 9 Examples, and Right Node with 497 Examples
# Creating Left Child Node With 5 Examples, and Right Node with 4 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=5, classes=[(2.0, 3), (3.0, 1), (4.0, 1)]
# Creating Child Node With ClassLabel=2.0, nexamples=4, classes=[(2.0, 4)]
# Creating Left Child Node With 328 Examples, and Right Node with 169 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=328, classes=[(2.0, 323), (4.0, 5)]
# Creating Child Node With ClassLabel=2.0, nexamples=169, classes=[(2.0, 169)]
# Creating Left Child Node With 1002 Examples, and Right Node with 998 Examples
# Creating Left Child Node With 982 Examples, and Right Node with 20 Examples
# Creating Left Child Node With 981 Examples, and Right Node with 1 Examples
# Creating Left Child Node With 487 Examples, and Right Node with 494 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=487, classes=[(1.0, 486), (4.0, 1)]
# Creating Child Node With ClassLabel=4.0, nexamples=494, classes=[(1.0, 3), (4.0, 491)]
# Creating Child Node With ClassLabel=1.0, nexamples=1, classes=[(1.0, 1)]
# Creating Left Child Node With 12 Examples, and Right Node with 8 Examples
# Creating Left Child Node With 11 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=11, classes=[(1.0, 5), (4.0, 6)]
# Creating Child Node With ClassLabel=1.0, nexamples=1, classes=[(1.0, 1)]
# Creating Left Child Node With 6 Examples, and Right Node with 2 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=6, classes=[(1.0, 1), (2.0, 3), (4.0, 2)]
# Creating Child Node With ClassLabel=1.0, nexamples=2, classes=[(1.0, 1), (3.0, 1)]
# Creating Left Child Node With 48 Examples, and Right Node with 950 Examples
# Creating Left Child Node With 7 Examples, and Right Node with 41 Examples
# Creating Left Child Node With 5 Examples, and Right Node with 2 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=5, classes=[(1.0, 2), (3.0, 3)]
# Creating Child Node With ClassLabel=2.0, nexamples=2, classes=[(2.0, 2)]
# Creating Left Child Node With 36 Examples, and Right Node with 5 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=36, classes=[(2.0, 27), (3.0, 9)]
# Creating Child Node With ClassLabel=3.0, nexamples=5, classes=[(2.0, 2), (3.0, 3)]
# Creating Left Child Node With 473 Examples, and Right Node with 477 Examples
# Creating Left Child Node With 378 Examples, and Right Node with 95 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=378, classes=[(3.0, 378)]
# Creating Child Node With ClassLabel=3.0, nexamples=95, classes=[(3.0, 95)]
# Creating Left Child Node With 371 Examples, and Right Node with 106 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=371, classes=[(2.0, 360), (3.0, 11)]
# Creating Child Node With ClassLabel=2.0, nexamples=106, classes=[(2.0, 106)]

# %%
len(rfc.trees)
# Out:
# 10

# %%
# Training Confusion Matrix...
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# (2000, 1) 2000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        493    0    4    3   500
# 2.0          0  500    0    0   500
# 3.0          0    1  499    0   500
# 4.0          1    2    0  497   500
# All        494  503  503  500  2000

# %%
#It might take time, a little longer than the desired
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('training-boundary-rf-raa-10trees.svg',format='svg')

# %%
#Testing Confusion Matrix...
Ypt=rfc.predict(Xt)
print Y.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Yt)
# Out:
# (2000, 1) 1000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        248    0    1    1   250
# 2.0          0  250    0    0   250
# 3.0          0    1  249    0   250
# 4.0          1    2    0  247   250
# All        249  253  250  248  1000

# %%
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('testing-boundary-rf-raa-10trees.svg',format='svg')

# %%
#plt.style.use('ggplot')
#matplotlib.rcParams['figure.figsize'] = (14.0, 8.0)
t.plot_points_range(rfc,X,Y,10000)
# Out:
# (10000, 2)
# [1.0, 2.0, 3.0, 4.0]

# %% [markdown]
# ###Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=0
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,np.squeeze(Y),clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_subplots.py:69: MatplotlibDeprecationWarning: The use of 0 (which ends up being the _last_ sub-plot) is deprecated in 1.4 and will raise an error in 1.5
#   mplDeprecation)
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# ####What Can You conclude

# %% [markdown]
# ##Lets Run on Nonlinear Data, The Spherical Examples...

# %%
#Get Training Data from a spherical distribution and ...
X,Y=t.get_spherical_data(N=10000)

# %%
#Get Test Data 
Xtest,Ytest=t.get_spherical_data(N=5000)

# %%
rfc=rf.RandomForest(weaklearner='Axis-Aligned-Random',usebagging=False)
rfc.train(X,Y)
# Out:
# Creating Left Child Node With 5677 Examples, and Right Node with 24323 Examples
# Creating Left Child Node With 3737 Examples, and Right Node with 1940 Examples
# Creating Left Child Node With 296 Examples, and Right Node with 3441 Examples
# Creating Left Child Node With 10 Examples, and Right Node with 286 Examples
# Creating Child Node With ClassLabel=0, nexamples=10, classes=[(0, 10)]
# Creating Child Node With ClassLabel=0, nexamples=286, classes=[(0, 286)]
# Creating Left Child Node With 252 Examples, and Right Node with 3189 Examples
# Creating Child Node With ClassLabel=2, nexamples=252, classes=[(0, 71), (2, 181)]
# Creating Child Node With ClassLabel=2, nexamples=3189, classes=[(0, 154), (2, 3035)]
# Creating Left Child Node With 1124 Examples, and Right Node with 816 Examples
# Creating Left Child Node With 313 Examples, and Right Node with 811 Examples
# Creating Child Node With ClassLabel=0, nexamples=313, classes=[(0, 313)]
# Creating Child Node With ClassLabel=2, nexamples=811, classes=[(2, 811)]
# Creating Left Child Node With 363 Examples, and Right Node with 453 Examples
# Creating Child Node With ClassLabel=2, nexamples=363, classes=[(0, 118), (1, 1), (2, 244)]
# Creating Child Node With ClassLabel=2, nexamples=453, classes=[(0, 149), (1, 21), (2, 283)]
# Creating Left Child Node With 18045 Examples, and Right Node with 6278 Examples
# Creating Left Child Node With 13054 Examples, and Right Node with 4991 Examples
# Creating Left Child Node With 7867 Examples, and Right Node with 5187 Examples
# Creating Child Node With ClassLabel=1, nexamples=7867, classes=[(0, 2166), (1, 3168), (2, 2533)]
# Creating Child Node With ClassLabel=2, nexamples=5187, classes=[(0, 2321), (2, 2866)]
# Creating Left Child Node With 4132 Examples, and Right Node with 859 Examples
# Creating Child Node With ClassLabel=0, nexamples=4132, classes=[(0, 4132)]
# Creating Child Node With ClassLabel=1, nexamples=859, classes=[(1, 859)]
# Creating Left Child Node With 2621 Examples, and Right Node with 3657 Examples
# Creating Left Child Node With 2574 Examples, and Right Node with 47 Examples
# Creating Child Node With ClassLabel=1, nexamples=2574, classes=[(1, 2574)]
# Creating Child Node With ClassLabel=2, nexamples=47, classes=[(2, 47)]
# Creating Left Child Node With 1551 Examples, and Right Node with 2106 Examples
# Creating Child Node With ClassLabel=1, nexamples=1551, classes=[(0, 277), (1, 1274)]
# Creating Child Node With ClassLabel=1, nexamples=2106, classes=[(0, 3), (1, 2103)]
# Creating Left Child Node With 3482 Examples, and Right Node with 26518 Examples
# Creating Left Child Node With 3228 Examples, and Right Node with 254 Examples
# Creating Left Child Node With 3227 Examples, and Right Node with 1 Examples
# Creating Left Child Node With 2862 Examples, and Right Node with 365 Examples
# Creating Child Node With ClassLabel=0, nexamples=2862, classes=[(0, 2862)]
# Creating Child Node With ClassLabel=0, nexamples=365, classes=[(0, 365)]
# Creating Child Node With ClassLabel=1, nexamples=1, classes=[(1, 1)]
# Creating Left Child Node With 49 Examples, and Right Node with 205 Examples
# Creating Left Child Node With 19 Examples, and Right Node with 30 Examples
# Creating Child Node With ClassLabel=0, nexamples=19, classes=[(0, 19)]
# Creating Child Node With ClassLabel=0, nexamples=30, classes=[(0, 22), (2, 8)]
# Creating Left Child Node With 200 Examples, and Right Node with 5 Examples
# Creating Child Node With ClassLabel=0, nexamples=200, classes=[(0, 200)]
# Creating Child Node With ClassLabel=0, nexamples=5, classes=[(0, 5)]
# Creating Left Child Node With 19459 Examples, and Right Node with 7059 Examples
# Creating Left Child Node With 8978 Examples, and Right Node with 10481 Examples
# Creating Left Child Node With 7909 Examples, and Right Node with 1069 Examples
# Creating Child Node With ClassLabel=2, nexamples=7909, classes=[(0, 1543), (1, 138), (2, 6228)]
# Creating Child Node With ClassLabel=0, nexamples=1069, classes=[(0, 732), (1, 337)]
# Creating Left Child Node With 2727 Examples, and Right Node with 7754 Examples
# Creating Child Node With ClassLabel=1, nexamples=2727, classes=[(0, 297), (1, 1534), (2, 896)]
# Creating Child Node With ClassLabel=0, nexamples=7754, classes=[(0, 3954), (1, 2693), (2, 1107)]
# Creating Left Child Node With 1588 Examples, and Right Node with 5471 Examples
# Creating Left Child Node With 715 Examples, and Right Node with 873 Examples
# Creating Child Node With ClassLabel=2, nexamples=715, classes=[(2, 715)]
# Creating Child Node With ClassLabel=2, nexamples=873, classes=[(2, 873)]
# Creating Left Child Node With 97 Examples, and Right Node with 5374 Examples
# Creating Child Node With ClassLabel=2, nexamples=97, classes=[(1, 1), (2, 96)]
# Creating Child Node With ClassLabel=1, nexamples=5374, classes=[(0, 1), (1, 5296), (2, 77)]
# Creating Left Child Node With 10739 Examples, and Right Node with 19261 Examples
# Creating Left Child Node With 3636 Examples, and Right Node with 7103 Examples
# Creating Left Child Node With 3633 Examples, and Right Node with 3 Examples
# Creating Left Child Node With 2327 Examples, and Right Node with 1306 Examples
# Creating Child Node With ClassLabel=0, nexamples=2327, classes=[(0, 2304), (2, 23)]
# Creating Child Node With ClassLabel=0, nexamples=1306, classes=[(0, 1306)]
# Creating Child Node With ClassLabel=1, nexamples=3, classes=[(1, 3)]
# Creating Left Child Node With 5240 Examples, and Right Node with 1863 Examples
# Creating Left Child Node With 128 Examples, and Right Node with 5112 Examples
# Creating Child Node With ClassLabel=0, nexamples=128, classes=[(0, 64), (2, 64)]
# Creating Child Node With ClassLabel=2, nexamples=5112, classes=[(0, 2), (2, 5110)]
# Creating Left Child Node With 885 Examples, and Right Node with 978 Examples
# Creating Child Node With ClassLabel=0, nexamples=885, classes=[(0, 845), (1, 40)]
# Creating Child Node With ClassLabel=0, nexamples=978, classes=[(0, 815), (1, 163)]
# Creating Left Child Node With 2970 Examples, and Right Node with 16291 Examples
# Creating Left Child Node With 2871 Examples, and Right Node with 99 Examples
# Creating Left Child Node With 7 Examples, and Right Node with 2864 Examples
# Creating Child Node With ClassLabel=2, nexamples=7, classes=[(0, 1), (2, 6)]
# Creating Child Node With ClassLabel=2, nexamples=2864, classes=[(2, 2864)]
# Creating Left Child Node With 63 Examples, and Right Node with 36 Examples
# Creating Child Node With ClassLabel=2, nexamples=63, classes=[(1, 3), (2, 60)]
# Creating Child Node With ClassLabel=2, nexamples=36, classes=[(1, 13), (2, 23)]
# Creating Left Child Node With 11137 Examples, and Right Node with 5154 Examples
# Creating Left Child Node With 4348 Examples, and Right Node with 6789 Examples
# Creating Child Node With ClassLabel=1, nexamples=4348, classes=[(0, 745), (1, 1975), (2, 1628)]
# Creating Child Node With ClassLabel=0, nexamples=6789, classes=[(0, 3918), (1, 2700), (2, 171)]
# Creating Left Child Node With 832 Examples, and Right Node with 4322 Examples
# Creating Child Node With ClassLabel=1, nexamples=832, classes=[(1, 787), (2, 45)]
# Creating Child Node With ClassLabel=1, nexamples=4322, classes=[(1, 4316), (2, 6)]
# Creating Left Child Node With 3964 Examples, and Right Node with 26036 Examples
# Creating Left Child Node With 2311 Examples, and Right Node with 1653 Examples
# Creating Left Child Node With 823 Examples, and Right Node with 1488 Examples
# Creating Left Child Node With 726 Examples, and Right Node with 97 Examples
# Creating Child Node With ClassLabel=0, nexamples=726, classes=[(0, 726)]
# Creating Child Node With ClassLabel=0, nexamples=97, classes=[(0, 96), (2, 1)]
# Creating Left Child Node With 1190 Examples, and Right Node with 298 Examples
# Creating Child Node With ClassLabel=0, nexamples=1190, classes=[(0, 1052), (2, 138)]
# Creating Child Node With ClassLabel=0, nexamples=298, classes=[(0, 289), (2, 9)]
# Creating Left Child Node With 1646 Examples, and Right Node with 7 Examples
# Creating Left Child Node With 38 Examples, and Right Node with 1608 Examples
# Creating Child Node With ClassLabel=0, nexamples=38, classes=[(0, 37), (2, 1)]
# Creating Child Node With ClassLabel=0, nexamples=1608, classes=[(0, 1608)]
# Creating Left Child Node With 2 Examples, and Right Node with 5 Examples
# Creating Child Node With ClassLabel=1, nexamples=2, classes=[(1, 2)]
# Creating Child Node With ClassLabel=1, nexamples=5, classes=[(1, 5)]
# Creating Left Child Node With 3999 Examples, and Right Node with 22037 Examples
# Creating Left Child Node With 42 Examples, and Right Node with 3957 Examples
# Creating Left Child Node With 8 Examples, and Right Node with 34 Examples
# Creating Child Node With ClassLabel=0, nexamples=8, classes=[(0, 8)]
# Creating Child Node With ClassLabel=2, nexamples=34, classes=[(0, 15), (2, 19)]
# Creating Left Child Node With 74 Examples, and Right Node with 3883 Examples
# Creating Child Node With ClassLabel=2, nexamples=74, classes=[(0, 16), (2, 58)]
# Creating Child Node With ClassLabel=2, nexamples=3883, classes=[(2, 3883)]
# Creating Left Child Node With 6838 Examples, and Right Node with 15199 Examples
# Creating Left Child Node With 4673 Examples, and Right Node with 2165 Examples
# Creating Child Node With ClassLabel=2, nexamples=4673, classes=[(1, 60), (2, 4613)]
# Creating Child Node With ClassLabel=0, nexamples=2165, classes=[(0, 1850), (1, 315)]
# Creating Left Child Node With 9869 Examples, and Right Node with 5330 Examples
# Creating Child Node With ClassLabel=1, nexamples=9869, classes=[(0, 4302), (1, 4428), (2, 1139)]
# Creating Child Node With ClassLabel=1, nexamples=5330, classes=[(0, 1), (1, 5190), (2, 139)]
# Creating Left Child Node With 6600 Examples, and Right Node with 23400 Examples
# Creating Left Child Node With 4504 Examples, and Right Node with 2096 Examples
# Creating Left Child Node With 2931 Examples, and Right Node with 1573 Examples
# Creating Left Child Node With 319 Examples, and Right Node with 2612 Examples
# Creating Child Node With ClassLabel=0, nexamples=319, classes=[(0, 319)]
# Creating Child Node With ClassLabel=2, nexamples=2612, classes=[(0, 34), (2, 2578)]
# Creating Left Child Node With 370 Examples, and Right Node with 1203 Examples
# Creating Child Node With ClassLabel=0, nexamples=370, classes=[(0, 370)]
# Creating Child Node With ClassLabel=2, nexamples=1203, classes=[(2, 1203)]
# Creating Left Child Node With 1090 Examples, and Right Node with 1006 Examples
# Creating Left Child Node With 268 Examples, and Right Node with 822 Examples
# Creating Child Node With ClassLabel=0, nexamples=268, classes=[(0, 268)]
# Creating Child Node With ClassLabel=2, nexamples=822, classes=[(0, 85), (1, 13), (2, 724)]
# Creating Left Child Node With 204 Examples, and Right Node with 802 Examples
# Creating Child Node With ClassLabel=0, nexamples=204, classes=[(0, 204)]
# Creating Child Node With ClassLabel=1, nexamples=802, classes=[(1, 409), (2, 393)]
# Creating Left Child Node With 17745 Examples, and Right Node with 5655 Examples
# Creating Left Child Node With 8592 Examples, and Right Node with 9153 Examples
# Creating Left Child Node With 2657 Examples, and Right Node with 5935 Examples
# Creating Child Node With ClassLabel=0, nexamples=2657, classes=[(0, 2551), (1, 7), (2, 99)]
# Creating Child Node With ClassLabel=2, nexamples=5935, classes=[(0, 1831), (1, 326), (2, 3778)]
# Creating Left Child Node With 2832 Examples, and Right Node with 6321 Examples
# Creating Child Node With ClassLabel=1, nexamples=2832, classes=[(0, 1), (1, 2831)]
# Creating Child Node With ClassLabel=0, nexamples=6321, classes=[(0, 4243), (1, 871), (2, 1207)]
# Creating Left Child Node With 2372 Examples, and Right Node with 3283 Examples
# Creating Left Child Node With 1544 Examples, and Right Node with 828 Examples
# Creating Child Node With ClassLabel=1, nexamples=1544, classes=[(1, 1527), (2, 17)]
# Creating Child Node With ClassLabel=1, nexamples=828, classes=[(1, 827), (2, 1)]
# Creating Left Child Node With 1562 Examples, and Right Node with 1721 Examples
# Creating Child Node With ClassLabel=1, nexamples=1562, classes=[(0, 94), (1, 1468)]
# Creating Child Node With ClassLabel=1, nexamples=1721, classes=[(1, 1721)]
# Creating Left Child Node With 9232 Examples, and Right Node with 20768 Examples
# Creating Left Child Node With 7019 Examples, and Right Node with 2213 Examples
# Creating Left Child Node With 2776 Examples, and Right Node with 4243 Examples
# Creating Left Child Node With 2039 Examples, and Right Node with 737 Examples
# Creating Child Node With ClassLabel=0, nexamples=2039, classes=[(0, 2023), (2, 16)]
# Creating Child Node With ClassLabel=0, nexamples=737, classes=[(0, 737)]
# Creating Left Child Node With 511 Examples, and Right Node with 3732 Examples
# Creating Child Node With ClassLabel=2, nexamples=511, classes=[(0, 53), (2, 458)]
# Creating Child Node With ClassLabel=2, nexamples=3732, classes=[(0, 25), (2, 3707)]
# Creating Left Child Node With 1091 Examples, and Right Node with 1122 Examples
# Creating Left Child Node With 1082 Examples, and Right Node with 9 Examples
# Creating Child Node With ClassLabel=0, nexamples=1082, classes=[(0, 1082)]
# Creating Child Node With ClassLabel=1, nexamples=9, classes=[(1, 9)]
# Creating Left Child Node With 1030 Examples, and Right Node with 92 Examples
# Creating Child Node With ClassLabel=0, nexamples=1030, classes=[(0, 1027), (2, 3)]
# Creating Child Node With ClassLabel=1, nexamples=92, classes=[(1, 92)]
# Creating Left Child Node With 8708 Examples, and Right Node with 12060 Examples
# Creating Left Child Node With 3246 Examples, and Right Node with 5462 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 3245 Examples
# Creating Child Node With ClassLabel=0, nexamples=1, classes=[(0, 1)]
# Creating Child Node With ClassLabel=2, nexamples=3245, classes=[(2, 3245)]
# Creating Left Child Node With 5329 Examples, and Right Node with 133 Examples
# Creating Child Node With ClassLabel=1, nexamples=5329, classes=[(0, 1), (1, 5328)]
# Creating Child Node With ClassLabel=2, nexamples=133, classes=[(1, 1), (2, 132)]
# Creating Left Child Node With 8575 Examples, and Right Node with 3485 Examples
# Creating Left Child Node With 7722 Examples, and Right Node with 853 Examples
# Creating Child Node With ClassLabel=0, nexamples=7722, classes=[(0, 5007), (1, 276), (2, 2439)]
# Creating Child Node With ClassLabel=1, nexamples=853, classes=[(1, 853)]
# Creating Left Child Node With 125 Examples, and Right Node with 3360 Examples
# Creating Child Node With ClassLabel=1, nexamples=125, classes=[(0, 41), (1, 84)]
# Creating Child Node With ClassLabel=1, nexamples=3360, classes=[(0, 3), (1, 3357)]
# Creating Left Child Node With 21600 Examples, and Right Node with 8400 Examples
# Creating Left Child Node With 2745 Examples, and Right Node with 18855 Examples
# Creating Left Child Node With 1001 Examples, and Right Node with 1744 Examples
# Creating Left Child Node With 60 Examples, and Right Node with 941 Examples
# Creating Child Node With ClassLabel=0, nexamples=60, classes=[(0, 60)]
# Creating Child Node With ClassLabel=0, nexamples=941, classes=[(0, 941)]
# Creating Left Child Node With 569 Examples, and Right Node with 1175 Examples
# Creating Child Node With ClassLabel=0, nexamples=569, classes=[(0, 556), (2, 13)]
# Creating Child Node With ClassLabel=0, nexamples=1175, classes=[(0, 1170), (2, 5)]
# Creating Left Child Node With 5672 Examples, and Right Node with 13183 Examples
# Creating Left Child Node With 129 Examples, and Right Node with 5543 Examples
# Creating Child Node With ClassLabel=0, nexamples=129, classes=[(0, 73), (2, 56)]
# Creating Child Node With ClassLabel=2, nexamples=5543, classes=[(0, 2), (2, 5541)]
# Creating Left Child Node With 2869 Examples, and Right Node with 10314 Examples
# Creating Child Node With ClassLabel=2, nexamples=2869, classes=[(1, 37), (2, 2832)]
# Creating Child Node With ClassLabel=1, nexamples=10314, classes=[(0, 2364), (1, 6415), (2, 1535)]
# Creating Left Child Node With 5390 Examples, and Right Node with 3010 Examples
# Creating Left Child Node With 4395 Examples, and Right Node with 995 Examples
# Creating Left Child Node With 519 Examples, and Right Node with 3876 Examples
# Creating Child Node With ClassLabel=0, nexamples=519, classes=[(0, 501), (2, 18)]
# Creating Child Node With ClassLabel=0, nexamples=3876, classes=[(0, 3876)]
# Creating Left Child Node With 812 Examples, and Right Node with 183 Examples
# Creating Child Node With ClassLabel=1, nexamples=812, classes=[(1, 812)]
# Creating Child Node With ClassLabel=1, nexamples=183, classes=[(1, 183)]
# Creating Left Child Node With 805 Examples, and Right Node with 2205 Examples
# Creating Left Child Node With 427 Examples, and Right Node with 378 Examples
# Creating Child Node With ClassLabel=0, nexamples=427, classes=[(0, 427)]
# Creating Child Node With ClassLabel=1, nexamples=378, classes=[(1, 378)]
# Creating Left Child Node With 99 Examples, and Right Node with 2106 Examples
# Creating Child Node With ClassLabel=1, nexamples=99, classes=[(0, 20), (1, 79)]
# Creating Child Node With ClassLabel=1, nexamples=2106, classes=[(0, 10), (1, 2096)]
# Creating Left Child Node With 21295 Examples, and Right Node with 8705 Examples
# Creating Left Child Node With 8653 Examples, and Right Node with 12642 Examples
# Creating Left Child Node With 2650 Examples, and Right Node with 6003 Examples
# Creating Left Child Node With 1005 Examples, and Right Node with 1645 Examples
# Creating Child Node With ClassLabel=0, nexamples=1005, classes=[(0, 1005)]
# Creating Child Node With ClassLabel=0, nexamples=1645, classes=[(0, 1636), (2, 9)]
# Creating Left Child Node With 239 Examples, and Right Node with 5764 Examples
# Creating Child Node With ClassLabel=2, nexamples=239, classes=[(0, 56), (2, 183)]
# Creating Child Node With ClassLabel=2, nexamples=5764, classes=[(0, 37), (1, 18), (2, 5709)]
# Creating Left Child Node With 7507 Examples, and Right Node with 5135 Examples
# Creating Left Child Node With 3282 Examples, and Right Node with 4225 Examples
# Creating Child Node With ClassLabel=1, nexamples=3282, classes=[(0, 15), (1, 1798), (2, 1469)]
# Creating Child Node With ClassLabel=0, nexamples=4225, classes=[(0, 2154), (1, 1461), (2, 610)]
# Creating Left Child Node With 2268 Examples, and Right Node with 2867 Examples
# Creating Child Node With ClassLabel=2, nexamples=2268, classes=[(1, 323), (2, 1945)]
# Creating Child Node With ClassLabel=1, nexamples=2867, classes=[(0, 66), (1, 2785), (2, 16)]
# Creating Left Child Node With 6897 Examples, and Right Node with 1808 Examples
# Creating Left Child Node With 5362 Examples, and Right Node with 1535 Examples
# Creating Left Child Node With 2376 Examples, and Right Node with 2986 Examples
# Creating Child Node With ClassLabel=0, nexamples=2376, classes=[(0, 2252), (1, 106), (2, 18)]
# Creating Child Node With ClassLabel=0, nexamples=2986, classes=[(0, 2290), (1, 655), (2, 41)]
# Creating Left Child Node With 751 Examples, and Right Node with 784 Examples
# Creating Child Node With ClassLabel=0, nexamples=751, classes=[(0, 485), (1, 266)]
# Creating Child Node With ClassLabel=1, nexamples=784, classes=[(0, 4), (1, 780)]
# Creating Left Child Node With 1005 Examples, and Right Node with 803 Examples
# Creating Left Child Node With 905 Examples, and Right Node with 100 Examples
# Creating Child Node With ClassLabel=1, nexamples=905, classes=[(1, 905)]
# Creating Child Node With ClassLabel=1, nexamples=100, classes=[(1, 100)]
# Creating Left Child Node With 211 Examples, and Right Node with 592 Examples
# Creating Child Node With ClassLabel=1, nexamples=211, classes=[(1, 211)]
# Creating Child Node With ClassLabel=1, nexamples=592, classes=[(1, 592)]
# Creating Left Child Node With 23821 Examples, and Right Node with 6179 Examples
# Creating Left Child Node With 5221 Examples, and Right Node with 18600 Examples
# Creating Left Child Node With 2720 Examples, and Right Node with 2501 Examples
# Creating Left Child Node With 172 Examples, and Right Node with 2548 Examples
# Creating Child Node With ClassLabel=2, nexamples=172, classes=[(0, 54), (2, 118)]
# Creating Child Node With ClassLabel=2, nexamples=2548, classes=[(0, 269), (2, 2279)]
# Creating Left Child Node With 627 Examples, and Right Node with 1874 Examples
# Creating Child Node With ClassLabel=0, nexamples=627, classes=[(0, 627)]
# Creating Child Node With ClassLabel=2, nexamples=1874, classes=[(1, 1), (2, 1873)]
# Creating Left Child Node With 15440 Examples, and Right Node with 3160 Examples
# Creating Left Child Node With 9639 Examples, and Right Node with 5801 Examples
# Creating Child Node With ClassLabel=1, nexamples=9639, classes=[(0, 2577), (1, 3882), (2, 3180)]
# Creating Child Node With ClassLabel=0, nexamples=5801, classes=[(0, 3340), (2, 2461)]
# Creating Left Child Node With 3071 Examples, and Right Node with 89 Examples
# Creating Child Node With ClassLabel=1, nexamples=3071, classes=[(1, 3071)]
# Creating Child Node With ClassLabel=2, nexamples=89, classes=[(2, 89)]
# Creating Left Child Node With 3952 Examples, and Right Node with 2227 Examples
# Creating Left Child Node With 1764 Examples, and Right Node with 2188 Examples
# Creating Left Child Node With 1628 Examples, and Right Node with 136 Examples
# Creating Child Node With ClassLabel=0, nexamples=1628, classes=[(0, 1628)]
# Creating Child Node With ClassLabel=1, nexamples=136, classes=[(1, 136)]
# Creating Left Child Node With 1941 Examples, and Right Node with 247 Examples
# Creating Child Node With ClassLabel=0, nexamples=1941, classes=[(0, 1394), (1, 547)]
# Creating Child Node With ClassLabel=1, nexamples=247, classes=[(0, 99), (1, 148)]
# Creating Left Child Node With 213 Examples, and Right Node with 2014 Examples
# Creating Left Child Node With 163 Examples, and Right Node with 50 Examples
# Creating Child Node With ClassLabel=1, nexamples=163, classes=[(0, 12), (1, 151)]
# Creating Child Node With ClassLabel=1, nexamples=50, classes=[(1, 50)]
# Creating Left Child Node With 1316 Examples, and Right Node with 698 Examples
# Creating Child Node With ClassLabel=1, nexamples=1316, classes=[(1, 1316)]
# Creating Child Node With ClassLabel=1, nexamples=698, classes=[(1, 698)]
# Creating Left Child Node With 21213 Examples, and Right Node with 8787 Examples
# Creating Left Child Node With 5874 Examples, and Right Node with 15339 Examples
# Creating Left Child Node With 1095 Examples, and Right Node with 4779 Examples
# Creating Left Child Node With 1048 Examples, and Right Node with 47 Examples
# Creating Child Node With ClassLabel=0, nexamples=1048, classes=[(0, 1048)]
# Creating Child Node With ClassLabel=0, nexamples=47, classes=[(0, 43), (2, 4)]
# Creating Left Child Node With 4317 Examples, and Right Node with 462 Examples
# Creating Child Node With ClassLabel=2, nexamples=4317, classes=[(0, 63), (1, 1), (2, 4253)]
# Creating Child Node With ClassLabel=2, nexamples=462, classes=[(1, 51), (2, 411)]
# Creating Left Child Node With 4722 Examples, and Right Node with 10617 Examples
# Creating Left Child Node With 1561 Examples, and Right Node with 3161 Examples
# Creating Child Node With ClassLabel=0, nexamples=1561, classes=[(0, 1561)]
# Creating Child Node With ClassLabel=2, nexamples=3161, classes=[(0, 2), (2, 3159)]
# Creating Left Child Node With 4863 Examples, and Right Node with 5754 Examples
# Creating Child Node With ClassLabel=1, nexamples=4863, classes=[(0, 492), (1, 2314), (2, 2057)]
# Creating Child Node With ClassLabel=1, nexamples=5754, classes=[(0, 1712), (1, 4006), (2, 36)]
# Creating Left Child Node With 6763 Examples, and Right Node with 2024 Examples
# Creating Left Child Node With 6451 Examples, and Right Node with 312 Examples
# Creating Left Child Node With 5126 Examples, and Right Node with 1325 Examples
# Creating Child Node With ClassLabel=0, nexamples=5126, classes=[(0, 5046), (2, 80)]
# Creating Child Node With ClassLabel=1, nexamples=1325, classes=[(1, 1325)]
# Creating Left Child Node With 33 Examples, and Right Node with 279 Examples
# Creating Child Node With ClassLabel=0, nexamples=33, classes=[(0, 33)]
# Creating Child Node With ClassLabel=1, nexamples=279, classes=[(1, 279)]
# Creating Left Child Node With 699 Examples, and Right Node with 1325 Examples
# Creating Left Child Node With 129 Examples, and Right Node with 570 Examples
# Creating Child Node With ClassLabel=1, nexamples=129, classes=[(1, 129)]
# Creating Child Node With ClassLabel=1, nexamples=570, classes=[(1, 570)]
# Creating Left Child Node With 388 Examples, and Right Node with 937 Examples
# Creating Child Node With ClassLabel=1, nexamples=388, classes=[(1, 388)]
# Creating Child Node With ClassLabel=1, nexamples=937, classes=[(1, 937)]

# %%
#Training Confusion Matrix
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# (30000,) 30000
# Predicted    0.0    1.0   2.0    All
# Actual
# 0           9870     67    63  10000
# 1            326   9658    16  10000
# 2             74   1257  8669  10000
# All        10270  10982  8748  30000

# %%
#Testing Confusion Matrix
Ypt=rfc.predict(Xtest)
print Y.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Ytest)
# Out:
# (30000,) 15000
# Predicted   0.0   1.0   2.0    All
# Actual
# 0          4949    25    26   5000
# 1           132  4864     4   5000
# 2            28   615  4357   5000
# All        5109  5504  4387  15000

# %%
t.plot_points_range(rfc,X,Y)
# Out:
# (10000, 2)
# [0.0, 1.0, 2.0]

# %%
t.plot_decision_regions(X,Y,rfc)

# %% [markdown]
# ###Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=0
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,Y,clf=tree);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# ##TODO: Find Optimal Number of Trees for this data set, using cross validation...
